# %% [markdown]
# # Сравнение сортировок
# ## Загрузка данных из файлов

# %%
import matplotlib.pyplot as plt
import csv
from math import sqrt

# %%
bubble_x = []
bubble_y = []
insertion_x = []
insertion_y = []
selection_x = []
selection_y = []

bubble_sqrt_y = []
insertion_sqrt_y = []
selection_sqrt_y = []


with open("../testing/data/bench1.txt") as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    
    for row in data:
        x = int(row[1])
        y = (int(row[2]) + int(row[3]) + int(row[4]) + int(row[5]) + int(row[6])) / 5
        
        if (row[0] == "Bubble sort"):
            bubble_x.append(x)
            bubble_y.append(y)
            bubble_sqrt_y.append(sqrt(y))
        elif (row[0] == "Insertion sort"):
            insertion_x.append(x)
            insertion_y.append(y)
            insertion_sqrt_y.append(sqrt(y))
        elif (row[0] == "Selection sort"):
            selection_x.append(x)
            selection_y.append(y)
            selection_sqrt_y.append(sqrt(y))

# %%
no_opt_x = []
no_opt_y = []
move_x = []
move_y = []
binsearch_x = []
binsearch_y = []


with open("../testing/data/bench5.txt") as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    
    for row in data:
        x = int(row[1])
        y = (int(row[2]) + int(row[3]) + int(row[4]) + int(row[5]) + int(row[6])) / 5
        
        if (row[0] == "No optimization insertion sort"):
            no_opt_x.append(x)
            no_opt_y.append(y)
        elif (row[0] == "Move optimization insertion sort"):
            move_x.append(x)
            move_y.append(y)
        elif (row[0] == "Binsearch optimization insertion sort"):
            binsearch_x.append(x)
            binsearch_y.append(y)

# %%
ran_x = []
ran_y = []
cen_x = []
cen_y = []
med_x = []
med_y = []


with open("../testing/data/bench2.txt") as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    
    for row in data:
        x = int(row[1])
        y = (int(row[2]) + int(row[3]) + int(row[4]) + int(row[5]) + int(row[6])) / 5
        
        if (row[0] == "Random pivot qsort"):
            ran_x.append(x)
            ran_y.append(y)
        elif (row[0] == "Central pivot qsort"):
            cen_x.append(x)
            cen_y.append(y)
        elif (row[0] == "Median pivot qsort"):
            med_x.append(x)
            med_y.append(y)

# %%
ran_ran1_x = []
ran_ran1_y = []
cen_ran1_x = []
cen_ran1_y = []
med_ran1_x = []
med_ran1_y = []

ran_sort1_x = []
ran_sort1_y = []
cen_sort1_x = []
cen_sort1_y = []
med_sort1_x = []
med_sort1_y = []

ran_id1_x = []
ran_id1_y = []
cen_id1_x = []
cen_id1_y = []
med_id1_x = []
med_id1_y = []

ran_rev1_x = []
ran_rev1_y = []
cen_rev1_x = []
cen_rev1_y = []
med_rev1_x = []
med_rev1_y = []

with open("../testing/data/bench6_1.txt") as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    
    for row in data:
        x = int(row[2])
        y = (int(row[3]) + int(row[4]) + int(row[5]) + int(row[6]) + int(row[7])) / 5
        
        if (row[0] == "Random pivot qsort"):
            if (row[1] == "reversed"):
                ran_rev1_x.append(x)
                ran_rev1_y.append(y)
            elif (row[1] == "sorted"):
                ran_sort1_x.append(x)
                ran_sort1_y.append(y)
            elif (row[1] == "identical"):
                ran_id1_x.append(x)
                ran_id1_y.append(y)
            elif (row[1] == "random"):
                ran_ran1_x.append(x)
                ran_ran1_y.append(y)
        elif (row[0] == "Central pivot qsort"):
            if (row[1] == "reversed"):
                cen_rev1_x.append(x)
                cen_rev1_y.append(y)
            elif (row[1] == "sorted"):
                cen_sort1_x.append(x)
                cen_sort1_y.append(y)
            elif (row[1] == "identical"):
                cen_id1_x.append(x)
                cen_id1_y.append(y)
            elif (row[1] == "random"):
                cen_ran1_x.append(x)
                cen_ran1_y.append(y)
        elif (row[0] == "Median pivot qsort"):
            if (row[1] == "reversed"):
                med_rev1_x.append(x)
                med_rev1_y.append(y)
            elif (row[1] == "sorted"):
                med_sort1_x.append(x)
                med_sort1_y.append(y)
            elif (row[1] == "identical"):
                med_id1_x.append(x)
                med_id1_y.append(y)
            elif (row[1] == "random"):
                med_ran1_x.append(x)
                med_ran1_y.append(y)

# %%
ran_ran2_x = []
ran_ran2_y = []
cen_ran2_x = []
cen_ran2_y = []
med_ran2_x = []
med_ran2_y = []

ran_sort2_x = []
ran_sort2_y = []
cen_sort2_x = []
cen_sort2_y = []
med_sort2_x = []
med_sort2_y = []

ran_id2_x = []
ran_id2_y = []
cen_id2_x = []
cen_id2_y = []
med_id2_x = []
med_id2_y = []

ran_rev2_x = []
ran_rev2_y = []
cen_rev2_x = []
cen_rev2_y = []
med_rev2_x = []
med_rev2_y = []

ran_anc2_x = []
ran_anc2_y = []
cen_anc2_x = []
cen_anc2_y = []
med_anc2_x = []
med_anc2_y = []

with open("../testing/data/bench6_2.txt") as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    
    for row in data:
        x = int(row[2])
        y = (int(row[3]) + int(row[4]) + int(row[5]) + int(row[6]) + int(row[7])) / 5
        
        if (row[0] == "Random pivot qsort"):
            if (row[1] == "reversed"):
                ran_rev2_x.append(x)
                ran_rev2_y.append(y)
            elif (row[1] == "sorted"):
                ran_sort2_x.append(x)
                ran_sort2_y.append(y)
            elif (row[1] == "identical"):
                ran_id2_x.append(x)
                ran_id2_y.append(y)
            elif (row[1] == "random"):
                ran_ran2_x.append(x)
                ran_ran2_y.append(y)
            elif (row[1] == "anti-mid"):
                ran_anc2_x.append(x)
                ran_anc2_y.append(y)
        elif (row[0] == "Central pivot qsort"):
            if (row[1] == "reversed"):
                cen_rev2_x.append(x)
                cen_rev2_y.append(y)
            elif (row[1] == "sorted"):
                cen_sort2_x.append(x)
                cen_sort2_y.append(y)
            elif (row[1] == "identical"):
                cen_id2_x.append(x)
                cen_id2_y.append(y)
            elif (row[1] == "random"):
                cen_ran2_x.append(x)
                cen_ran2_y.append(y)
            elif (row[1] == "anti-mid"):
                cen_anc2_x.append(x)
                cen_anc2_y.append(y)
        elif (row[0] == "Median pivot qsort"):
            if (row[1] == "reversed"):
                med_rev2_x.append(x)
                med_rev2_y.append(y)
            elif (row[1] == "sorted"):
                med_sort2_x.append(x)
                med_sort2_y.append(y)
            elif (row[1] == "identical"):
                med_id2_x.append(x)
                med_id2_y.append(y)
            elif (row[1] == "random"):
                med_ran2_x.append(x)
                med_ran2_y.append(y)
            elif (row[1] == "anti-mid"):
                med_anc2_x.append(x)
                med_anc2_y.append(y)

# %%
merge_x = []
merge_y = []

with open("../testing/data/bench3.txt") as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    
    for row in data:
        x = int(row[1])
        y = (int(row[2]) + int(row[3]) + int(row[4]) + int(row[5]) + int(row[6])) / 5
    
        merge_x.append(x)
        merge_y.append(y)

# %%
merge0_x = []
merge0_y = []
merge5_x = []
merge5_y = []
merge10_x = []
merge10_y = []
merge25_x = []
merge25_y = []
merge50_x = []
merge50_y = []
merge75_x = []
merge75_y = []
merge100_x = []
merge100_y = []


with open("../testing/data/bench3_cmp2.txt") as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    
    for row in data:
        x = int(row[2])
        y = (int(row[3]) + int(row[4]) + int(row[5]) + int(row[6]) + int(row[7])) / 5
        
        if (row[0] == "Merge sort" and row[1] == "0"):
            merge0_x.append(x)
            merge0_y.append(y)
        elif (row[0] == "Merge sort" and row[1] == "5"):
            merge5_x.append(x)
            merge5_y.append(y)
        elif (row[0] == "Merge sort" and row[1] == "10"):
            merge10_x.append(x)
            merge10_y.append(y)
        elif (row[0] == "Merge sort" and row[1] == "25"):
            merge25_x.append(x)
            merge25_y.append(y)
        elif (row[0] == "Merge sort" and row[1] == "50"):
            merge50_x.append(x)
            merge50_y.append(y)
        elif (row[0] == "Merge sort" and row[1] == "75"):
            merge75_x.append(x)
            merge75_y.append(y)
        elif (row[0] == "Merge sort" and row[1] == "100"):
            merge100_x.append(x)
            merge100_y.append(y)

# %%
lsd_x = []
lsd_y = []

with open("../testing/data/bench4.txt") as csvfile:
    data = csv.reader(csvfile, delimiter=',')
    
    for row in data:
        x = int(row[1])
        y = (int(row[2]) + int(row[3]) + int(row[4]) + int(row[5]) + int(row[6])) / 5
    
        lsd_x.append(x)
        lsd_y.append(y)

# %% [markdown]
# ## Quadratic sortings

# %% [markdown]
# ### Sortings comparison

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Quadratic sortings comparison', fontsize = 15)

plt.plot(bubble_x, bubble_y)
plt.plot(insertion_x, insertion_y)
plt.plot(selection_x, selection_y)

plt.legend(['bubble', 'insertion', 'selection'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Quadratic sortings comparison: linearization', fontsize = 15)

plt.plot(bubble_x, bubble_sqrt_y)
plt.plot(insertion_x, insertion_sqrt_y)
plt.plot(selection_x, selection_sqrt_y)

plt.legend(['bubble', 'insertion', 'selection'])

plt.show()

# %% [markdown]
# ### Insertion sort optimizations

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Insertion sort optimizations comparison', fontsize = 15)

plt.plot(no_opt_x, no_opt_y)
plt.plot(move_x, move_y)
plt.plot(binsearch_x, binsearch_y)

plt.legend(['No optimization', 'Moving', 'Moving + Binary search'])

plt.show()

# %% [markdown]
# ### Insertion after optimization vs Selection

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Insertion vs Selection', fontsize = 15)

plt.plot(no_opt_x, no_opt_y)
plt.plot(binsearch_x, binsearch_y)
plt.plot(selection_x, selection_y)

plt.legend(['Insertion before', 'Insertion after', 'Selection'])

plt.show()

# %% [markdown]
# ## QSORT

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Qsort sortings comparison', fontsize = 15)

plt.plot(ran_x, ran_y)
plt.plot(cen_x, cen_y)
plt.plot(med_x, med_y)

plt.legend(['random', 'central', 'median'])

plt.show()

# %% [markdown]
# ### QuickSort and specifical cases of arrays

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Qsort sortings on random array', fontsize = 15)

plt.plot(ran_ran1_x, ran_ran1_y)
plt.plot(cen_ran1_x, cen_ran1_y)
plt.plot(med_ran1_x, med_ran1_y)

plt.legend(['random', 'central', 'median'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Qsort sortings on array of equal elements', fontsize = 15)

plt.plot(ran_id1_x, ran_id1_y)
plt.plot(cen_id1_x, cen_id1_y)
plt.plot(med_id1_x, med_id1_y)

plt.legend(['random', 'central', 'median'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Qsort sortings on sorted array', fontsize = 15)

plt.plot(ran_sort1_x, ran_sort1_y)
plt.plot(cen_sort1_x, cen_sort1_y)
plt.plot(med_sort1_x, med_sort1_y)

plt.legend(['random', 'central', 'median'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Qsort sortings on reversed sorted array', fontsize = 15)

plt.plot(ran_rev1_x, ran_rev1_y)
plt.plot(cen_rev1_x, cen_rev1_y)
plt.plot(med_rev1_x, med_rev1_y)

plt.legend(['random', 'central', 'median'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Qsort sortings on anti-central array', fontsize = 15)

plt.plot(ran_anc2_x, ran_anc2_y)
plt.plot(cen_anc2_x, cen_anc2_y)
plt.plot(med_anc2_x, med_anc2_y)

plt.legend(['random', 'central', 'median'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Random pivot on different arrays', fontsize = 15)

plt.plot(ran_ran1_x,  ran_ran1_y)
plt.plot(ran_rev1_x,  ran_rev1_y)
plt.plot(ran_id1_x,   ran_id1_y)
plt.plot(ran_sort1_x, ran_sort1_y)

plt.legend(['random', 'reversed sorted', 'identical', 'sorted'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Random pivot on different arrays', fontsize = 15)

plt.plot(ran_ran2_x,  ran_ran2_y)
plt.plot(ran_rev2_x,  ran_rev2_y)
plt.plot(ran_id2_x,   ran_id2_y)
plt.plot(ran_sort2_x, ran_sort2_y)
plt.plot(ran_anc2_x, ran_anc2_y)

plt.legend(['random', 'reversed sorted', 'identical', 'sorted', 'anti-central'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Median pivot on different arrays', fontsize = 15)

plt.plot(med_ran1_x,  med_ran1_y)
plt.plot(med_rev1_x,  med_rev1_y)
plt.plot(med_id1_x,   med_id1_y)
plt.plot(med_sort1_x, med_sort1_y)

plt.legend(['random', 'reversed sorted', 'identical', 'sorted'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Median pivot on different arrays', fontsize = 15)

plt.plot(med_ran2_x,  med_ran2_y)
plt.plot(med_rev2_x,  med_rev2_y)
plt.plot(med_id2_x,   med_id2_y)
plt.plot(med_sort2_x, med_sort2_y)
plt.plot(med_anc2_x,  med_anc2_y)

plt.legend(['random', 'reversed sorted', 'identical', 'sorted', 'anti-central'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Central pivot on different arrays', fontsize = 15)

plt.plot(cen_ran1_x,  cen_ran1_y)
plt.plot(cen_rev1_x,  cen_rev1_y)
plt.plot(cen_id1_x,   cen_id1_y)
plt.plot(cen_sort1_x, cen_sort1_y)

plt.legend(['random', 'reversed sorted', 'identical', 'sorted'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Central pivot on different arrays', fontsize = 15)

plt.plot(cen_ran2_x,  cen_ran2_y)
plt.plot(cen_rev2_x,  cen_rev2_y)
plt.plot(cen_id2_x,   cen_id2_y)
plt.plot(cen_sort2_x, cen_sort2_y)
plt.plot(cen_anc2_x, cen_anc2_y)

plt.legend(['random', 'reversed sorted', 'identical', 'sorted', 'anti-central'])

plt.show()

# %% [markdown]
# ## MergeSort

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Merge sort plot', fontsize = 15)

plt.plot(merge_x, merge_y)

plt.legend(['merge'])

plt.show()

# %% [markdown]
# ### Merge sort optimization: insertion sort for subarrays

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Merge sort optimization: using insertion sort', fontsize = 15)

plt.plot(merge0_x, merge0_y)
plt.plot(merge5_x, merge5_y)
plt.plot(merge10_x, merge10_y)
plt.plot(merge25_x, merge25_y)
plt.plot(merge50_x, merge50_y)
plt.plot(merge75_x, merge75_y)
plt.plot(merge100_x, merge100_y)

plt.legend(['No optimization', 'Switch at 5', 'Switch at 10', 'Switch at 25', 'Switch at 50', 
            'Switch at 75', 'Switch at 100'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Merge sort optimization: using insertion sort', fontsize = 15)

plt.plot(merge5_x, merge5_y)
plt.plot(merge10_x, merge10_y)
plt.plot(merge25_x, merge25_y)
plt.plot(merge50_x, merge50_y)
plt.plot(merge75_x, merge75_y)
plt.plot(merge100_x, merge100_y)

plt.legend(['Switch at 5', 'Switch at 10', 'Switch at 25', 'Switch at 50', 
            'Switch at 75', 'Switch at 100'])

plt.show()

# %%
merge_x = [5, 10, 25, 50, 75, 100]

merge0_y = []
merge2_y = []
merge4_y = []
merge6_y = []
merge8_y = []


merge0_y.append(merge5_y[0])
merge0_y.append(merge10_y[0])
merge0_y.append(merge25_y[0])
merge0_y.append(merge50_y[0])
merge0_y.append(merge75_y[0])
merge0_y.append(merge100_y[0])

merge2_y.append(merge5_y[4])
merge2_y.append(merge10_y[4])
merge2_y.append(merge25_y[4])
merge2_y.append(merge50_y[4])
merge2_y.append(merge75_y[4])
merge2_y.append(merge100_y[4])

merge4_y.append(merge5_y[8])
merge4_y.append(merge10_y[8])
merge4_y.append(merge25_y[8])
merge4_y.append(merge50_y[8])
merge4_y.append(merge75_y[8])
merge4_y.append(merge100_y[8])

merge6_y.append(merge5_y[12])
merge6_y.append(merge10_y[12])
merge6_y.append(merge25_y[12])
merge6_y.append(merge50_y[12])
merge6_y.append(merge75_y[12])
merge6_y.append(merge100_y[12])

merge8_y.append(merge5_y[16])
merge8_y.append(merge10_y[16])
merge8_y.append(merge25_y[16])
merge8_y.append(merge50_y[16])
merge8_y.append(merge75_y[16])
merge8_y.append(merge100_y[16])

# %%
plt.xlabel('Min size for switch', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Merge sort optimization: using insertion sort', fontsize = 15)

plt.plot(merge_x, merge2_y)
plt.plot(merge_x, merge4_y)
plt.plot(merge_x, merge6_y)
plt.plot(merge_x, merge8_y)

plt.legend(['2001000', '4001000', '6001000', '8001000'])

plt.show()

# %%
plt.xlabel('Min size for switch', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Merge sort optimization: using insertion sort', fontsize = 15)

plt.plot(merge_x, merge2_y)

plt.legend(['2001000'])

plt.show()

# %%
plt.xlabel('Min size for switch', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Merge sort optimization: using insertion sort', fontsize = 15)

plt.plot(merge_x, merge4_y)

plt.legend(['4001000'])

plt.show()

# %%
plt.xlabel('Min size for switch', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Merge sort optimization: using insertion sort', fontsize = 15)

plt.plot(merge_x, merge6_y)

plt.legend(['6001000'])

plt.show()

# %%
plt.xlabel('Min size for switch', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('Merge sort optimization: using insertion sort', fontsize = 15)

plt.plot(merge_x, merge8_y)

plt.legend(['8001000'])

plt.show()

# %% [markdown]
# ## LSD sort

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('LSD sort plot', fontsize = 15)

plt.plot(lsd_x, lsd_y)

plt.legend(['LSD'])

plt.show()

# %% [markdown]
# ## All sortings comparison

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('All sortings comparison with quadratic', fontsize = 15)

plt.plot(selection_x, selection_y)
plt.plot(ran_x, ran_y)
plt.plot(cen_x, cen_y)
plt.plot(med_x, med_y)
plt.plot(merge10_x, merge10_y)
plt.plot(lsd_x, lsd_y)

plt.legend(['selection sort', 'random', 'central', 'median', 'merge', 'LSD'])

plt.show()

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('All sortings comparison without quadratic', fontsize = 15)

plt.plot(ran_x, ran_y)
plt.plot(cen_x, cen_y)
plt.plot(med_x, med_y)
plt.plot(merge10_x, merge10_y)
plt.plot(lsd_x, lsd_y)

plt.legend(['random', 'central', 'median', 'merge', 'LSD'])

plt.show()

# %% [markdown]
# ## Выводы
#
# LSD сортровка работает быстрее остальных, но не является универсальной, используя информацию о структуре сортируемых объектов. В частном случае сравнения чисел она хороша по времени. Среди логарифмических сортировок лидирует qsort с выбором среднего по номеру элемента, вероятно за счет отсутствия необходимости дополнительных вычислений. Merge в среднем работает чуть хуже избавленных от случайности вариантов qsort, однако лучше версии с выбором случайного опорного элемента. Квадратичные сортировки, очевидно, работают гораздо хуже логарифмтческих по времени, поэтому не были включены в итоговый график. В сравнении квадратичных сортировок удивило то, что пузырьковая в несколько раз отстает от сортровки выбором.
